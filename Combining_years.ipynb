# %%
import numpy as np
import pandas as pd

# %%
xls = pd.ExcelFile('gesamtdatei_stundenwerte1.xlsx')
df1 = pd.read_excel(xls, 'Jahresdatei 2021')
df1
# Out:
#      Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0                 2021-01-01 00:00:00                     5.0
# 1                 2021-01-01 01:00:00                    21.0
# 2                 2021-01-01 02:00:00                    28.0
# 3                 2021-01-01 03:00:00                    36.0
# 4                 2021-01-01 04:00:00                    24.0
# ...                               ...                     ...
# 8755              2021-12-31 19:00:00                    32.0
# 8756              2021-12-31 20:00:00                    17.0
# 8757              2021-12-31 21:00:00                    13.0
# 8758              2021-12-31 22:00:00                    25.0
# 8759              2021-12-31 23:00:00                    10.0
#
#       02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# 0                        6.0                     4.0                     2.0
# ...

# %%
xls2 = pd.ExcelFile('gesamtdatei_stundenwerte1.xlsx')
df2 = pd.read_excel(xls2, 'Jahresdatei 2020')
df2
# Out:
#      Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0                 2020-01-01 00:00:00                    12.0
# 1                 2020-01-01 01:00:00                    15.0
# 2                 2020-01-01 02:00:00                    16.0
# 3                 2020-01-01 03:00:00                    25.0
# 4                 2020-01-01 04:00:00                    21.0
# ...                               ...                     ...
# 8779              2020-12-31 19:00:00                    73.0
# 8780              2020-12-31 20:00:00                    38.0
# 8781              2020-12-31 21:00:00                    29.0
# 8782              2020-12-31 22:00:00                    16.0
# 8783              2020-12-31 23:00:00                    15.0
#
#       02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# 0                       15.0                     8.0                     8.0
# ...

# %%
df=df1.append(df2)
df
# Out:
#      Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0                 2021-01-01 00:00:00                     5.0
# 1                 2021-01-01 01:00:00                    21.0
# 2                 2021-01-01 02:00:00                    28.0
# 3                 2021-01-01 03:00:00                    36.0
# 4                 2021-01-01 04:00:00                    24.0
# ...                               ...                     ...
# 8779              2020-12-31 19:00:00                    73.0
# 8780              2020-12-31 20:00:00                    38.0
# 8781              2020-12-31 21:00:00                    29.0
# 8782              2020-12-31 22:00:00                    16.0
# 8783              2020-12-31 23:00:00                    15.0
#
#       02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# 0                        6.0                     4.0                     2.0
# ...

# %%
xls3 = pd.ExcelFile('gesamtdatei_stundenwerte1.xlsx')
df3 = pd.read_excel(xls3, 'Jahresdatei 2019')
df3
# Out:
#      Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0                 2019-01-01 00:00:00                    11.0
# 1                 2019-01-01 01:00:00                    16.0
# 2                 2019-01-01 02:00:00                    19.0
# 3                 2019-01-01 03:00:00                    19.0
# 4                 2019-01-01 04:00:00                    13.0
# ...                               ...                     ...
# 8754              2019-12-31 19:00:00                    45.0
# 8755              2019-12-31 20:00:00                    30.0
# 8756              2019-12-31 21:00:00                    22.0
# 8757              2019-12-31 22:00:00                    22.0
# 8758              2019-12-31 23:00:00                    13.0
#
#       02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# 0                       13.0                     0.0                     8.0
# ...

# %%
df_all=df.append(df3)
df_all
# Out:
#      Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0                 2021-01-01 00:00:00                     5.0
# 1                 2021-01-01 01:00:00                    21.0
# 2                 2021-01-01 02:00:00                    28.0
# 3                 2021-01-01 03:00:00                    36.0
# 4                 2021-01-01 04:00:00                    24.0
# ...                               ...                     ...
# 8754              2019-12-31 19:00:00                    45.0
# 8755              2019-12-31 20:00:00                    30.0
# 8756              2019-12-31 21:00:00                    22.0
# 8757              2019-12-31 22:00:00                    22.0
# 8758              2019-12-31 23:00:00                    13.0
#
#       02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# 0                        6.0                     4.0                     2.0
# ...

# %%
xls4 = pd.ExcelFile('gesamtdatei_stundenwerte1.xlsx')
df4 = pd.read_excel(xls4, 'Jahresdatei 2018')
df4
# Out:
#      Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0                 2018-01-01 00:00:00                      12
# 1                 2018-01-01 01:00:00                      17
# 2                 2018-01-01 02:00:00                      25
# 3                 2018-01-01 03:00:00                      18
# 4                 2018-01-01 04:00:00                      15
# ...                               ...                     ...
# 8755              2018-12-31 19:00:00                      36
# 8756              2018-12-31 20:00:00                      32
# 8757              2018-12-31 21:00:00                      25
# 8758              2018-12-31 22:00:00                      21
# 8759              2018-12-31 23:00:00                      26
#
#       02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# 0                          9                      15                       1
# ...

# %%
df_years=df_all.append(df4)
df_years
# Out:
#      Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0                 2021-01-01 00:00:00                     5.0
# 1                 2021-01-01 01:00:00                    21.0
# 2                 2021-01-01 02:00:00                    28.0
# 3                 2021-01-01 03:00:00                    36.0
# 4                 2021-01-01 04:00:00                    24.0
# ...                               ...                     ...
# 8755              2018-12-31 19:00:00                    36.0
# 8756              2018-12-31 20:00:00                    32.0
# 8757              2018-12-31 21:00:00                    25.0
# 8758              2018-12-31 22:00:00                    21.0
# 8759              2018-12-31 23:00:00                    26.0
#
#       02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# 0                        6.0                     4.0                     2.0
# ...

# %%
xls5= pd.ExcelFile('gesamtdatei_stundenwerte1.xlsx')
df5 = pd.read_excel(xls5, 'Jahresdatei 2017')
df5
# Out:
#      Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0                 2017-01-01 00:00:00                       6
# 1                 2017-01-01 01:00:00                      23
# 2                 2017-01-01 02:00:00                      17
# 3                 2017-01-01 03:00:00                      22
# 4                 2017-01-01 04:00:00                      14
# ...                               ...                     ...
# 8755              2017-12-31 19:00:00                      29
# 8756              2017-12-31 20:00:00                      31
# 8757              2017-12-31 21:00:00                      21
# 8758              2017-12-31 22:00:00                      11
# 8759              2017-12-31 23:00:00                       7
#
#       02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# 0                          5                       4                       5
# ...

# %%
df_5years=df_years.append(df5)
df_5years
# Out:
#      Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0                 2021-01-01 00:00:00                     5.0
# 1                 2021-01-01 01:00:00                    21.0
# 2                 2021-01-01 02:00:00                    28.0
# 3                 2021-01-01 03:00:00                    36.0
# 4                 2021-01-01 04:00:00                    24.0
# ...                               ...                     ...
# 8755              2017-12-31 19:00:00                    29.0
# 8756              2017-12-31 20:00:00                    31.0
# 8757              2017-12-31 21:00:00                    21.0
# 8758              2017-12-31 22:00:00                    11.0
# 8759              2017-12-31 23:00:00                     7.0
#
#       02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# 0                        6.0                     4.0                     2.0
# ...

# %%
df_5years = df_5years.drop(['05-FK-OBB-O 01.06.2015', '05-FK-OBB-W 01.06.2015', '06-CW-JU-O 27.07.2021', '06-CW-JU-W 27.07.2021', '02-MI-AL-W 16.12.2021'  ], axis=1)
df_5years
# Out:
#      Zählstelle        Inbetriebnahme  Jannowitzbrücke Nord  \
# 0                 2021-01-01 00:00:00                   5.0
# 1                 2021-01-01 01:00:00                  21.0
# 2                 2021-01-01 02:00:00                  28.0
# 3                 2021-01-01 03:00:00                  36.0
# 4                 2021-01-01 04:00:00                  24.0
# ...                               ...                   ...
# 8755              2017-12-31 19:00:00                  29.0
# 8756              2017-12-31 20:00:00                  31.0
# 8757              2017-12-31 21:00:00                  21.0
# 8758              2017-12-31 22:00:00                  11.0
# 8759              2017-12-31 23:00:00                   7.0
#
#       Jannowitzbrücke Süd  Invalidenstraße Ost  Invalidenstraße West  \
# 0                     6.0                  4.0                   2.0
# 1                    14.0                 12.0                  18.0
# ...

# %%
df_5years= df_5years.rename(columns={'02-MI-JAN-N 01.04.2015': 'Jannowitzbrücke Nord', '02-MI-JAN-S 01.04.2015': 'Jannowitzbrücke Süd',
                         '03-MI-SAN-O 01.06.2015': 'Invalidenstraße Ost', '03-MI-SAN-W 01.06.2015': 'Invalidenstraße West',
                         '06-FK-FRA-O 01.06.2016': 'Frankfurter Allee Ost', '06-FK-FRA-W 01.06.2016': 'Frankfurter Allee West',
                         '10-PA-BER-N 01.05.2016': 'Berliner Straße Nord', '10-PA-BER-S 01.05.2016': 'Berliner Straße Süd',
                         '12-PA-SCH 01.03.2012': 'Schwedter Steg', '13-CW-PRI 01.04.2015': 'Prinzregentenstraße',
                         '15-SP-KLO-N 01.06.2016': 'Klosterstraße Nord', '15-SP-KLO-S 01.06.2016': 'Klosterstraße Süd',
                         '17-SZ-BRE-O 01.05.2016': 'Breitenbachplatz Ost', '17-SZ-BRE-W 01.05.2016': 'Breitenbachplatz West',
                         '18-TS-YOR-O 01.04.2015': 'Yorckstraße Ost', '18-TS-YOR-W 01.04.2015': 'Yorkstraße West',
                         '19-TS-MON 01.05.2015': 'Monumentenstraße', '20-TS-MAR-N  01.05.2016': 'Mariendorfer Damm Nord',
                         '20-TS-MAR-S 01.05.2016': 'Mariendorfer Damm Süd', '21-NK-MAY 01.05.2016': 'Maybachufer',
                         '23-TK-KAI 01.05.2016': 'Kaisersteg', '24-MH-ALB 01.07.2015': 'Alberichstraße',
                         '26-LI-PUP 01.06.2015': 'Paul-und-Paula-Uferweg', '27-RE-MAR 01.05.2015': 'Markstraße'})
df_5years
# Out:
#      Zählstelle        Inbetriebnahme  Jannowitzbrücke Nord  \
# 0                 2021-01-01 00:00:00                   5.0
# 1                 2021-01-01 01:00:00                  21.0
# 2                 2021-01-01 02:00:00                  28.0
# 3                 2021-01-01 03:00:00                  36.0
# 4                 2021-01-01 04:00:00                  24.0
# ...                               ...                   ...
# 8755              2017-12-31 19:00:00                  29.0
# 8756              2017-12-31 20:00:00                  31.0
# 8757              2017-12-31 21:00:00                  21.0
# 8758              2017-12-31 22:00:00                  11.0
# 8759              2017-12-31 23:00:00                   7.0
#
#       Jannowitzbrücke Süd  Invalidenstraße Ost  Invalidenstraße West  \
# 0                     6.0                  4.0                   2.0
# 1                    14.0                 12.0                  18.0
# ...

# %%
df_5years['date'] = df_5years['Zählstelle        Inbetriebnahme'].dt.date
df_5years['Time'] = df_5years['Zählstelle        Inbetriebnahme'].dt.time


df_5years
# Out:
#      Zählstelle        Inbetriebnahme  Jannowitzbrücke Nord  \
# 0                 2021-01-01 00:00:00                   5.0
# 1                 2021-01-01 01:00:00                  21.0
# 2                 2021-01-01 02:00:00                  28.0
# 3                 2021-01-01 03:00:00                  36.0
# 4                 2021-01-01 04:00:00                  24.0
# ...                               ...                   ...
# 8755              2017-12-31 19:00:00                  29.0
# 8756              2017-12-31 20:00:00                  31.0
# 8757              2017-12-31 21:00:00                  21.0
# 8758              2017-12-31 22:00:00                  11.0
# 8759              2017-12-31 23:00:00                   7.0
#
#       Jannowitzbrücke Süd  Invalidenstraße Ost  Invalidenstraße West  \
# 0                     6.0                  4.0                   2.0
# 1                    14.0                 12.0                  18.0
# ...

# %%
df_5years.to_excel("5_years_together.xlsx")

# %%
df_5years.isna()
# Out:
#       Zählstelle        Inbetriebnahme  Jannowitzbrücke Nord  \
# 0                                False                 False
# 1                                False                 False
# 2                                False                 False
# 3                                False                 False
# 4                                False                 False
# ...                                ...                   ...
# 8755                             False                 False
# 8756                             False                 False
# 8757                             False                 False
# 8758                             False                 False
# 8759                             False                 False
#
#       Jannowitzbrücke Süd  Invalidenstraße Ost  Invalidenstraße West  \
# 0                   False                False                 False
# 1                   False                False                 False
# ...

# %%
df_5years.isna().sum()
# Out:
# Zählstelle        Inbetriebnahme      0
# Jannowitzbrücke Nord                  4
# Jannowitzbrücke Süd                   4
# Invalidenstraße Ost                   4
# Invalidenstraße West                 12
# Frankfurter Allee Ost                13
# Frankfurter Allee West                4
# Berliner Straße Nord                  4
# Berliner Straße Süd                   5
# Schwedter Steg                        3
# Prinzregentenstraße                   4
# Klosterstraße Nord                   19
# Klosterstraße Süd                     4
# Breitenbachplatz Ost                  4
# Breitenbachplatz West                 4
# Yorckstraße Ost                      15
# Yorkstraße West                       4
# Monumentenstraße                     15
# Mariendorfer Damm Nord                4
# Mariendorfer Damm Süd               488
# Maybachufer                           4
# Kaisersteg                          214
# Alberichstraße                        2
# ...

# %%
xls6= pd.ExcelFile('gesamtdatei_stundenwerte_with_2022.xlsx')
df6 = pd.read_excel(xls6, 'Jahresdatei 2022')
df6
# Out:
#      Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0                 2022-01-01 00:00:00                    10.0
# 1                 2022-01-01 01:00:00                    22.0
# 2                 2022-01-01 02:00:00                    25.0
# 3                 2022-01-01 03:00:00                    12.0
# 4                 2022-01-01 04:00:00                     8.0
# ...                               ...                     ...
# 8755              2022-12-31 19:00:00                    36.0
# 8756              2022-12-31 20:00:00                    32.0
# 8757              2022-12-31 21:00:00                    24.0
# 8758              2022-12-31 22:00:00                    32.0
# 8759              2022-12-31 23:00:00                    22.0
#
#       02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# 0                       11.0                     9.0                     8.0
# ...

# %%
df6= df6.drop(['05-FK-OBB-O 02.05.2022', '05-FK-OBB-W 02.05.2022', '14-CW-JU-O 27.07.2021', '14-CW-JU-W 27.07.2021', '01-MI-AL-W 16.12.2021' ], axis=1)
df6
# Out:
#      Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0                 2022-01-01 00:00:00                    10.0
# 1                 2022-01-01 01:00:00                    22.0
# 2                 2022-01-01 02:00:00                    25.0
# 3                 2022-01-01 03:00:00                    12.0
# 4                 2022-01-01 04:00:00                     8.0
# ...                               ...                     ...
# 8755              2022-12-31 19:00:00                    36.0
# 8756              2022-12-31 20:00:00                    32.0
# 8757              2022-12-31 21:00:00                    24.0
# 8758              2022-12-31 22:00:00                    32.0
# 8759              2022-12-31 23:00:00                    22.0
#
#       02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# 0                       11.0                     9.0                     8.0
# ...

# %%
df6= df6.drop(['11-PA-SE-N\n06.10.2022' ], axis=1)
df6
# Out:
#      Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0                 2022-01-01 00:00:00                    10.0
# 1                 2022-01-01 01:00:00                    22.0
# 2                 2022-01-01 02:00:00                    25.0
# 3                 2022-01-01 03:00:00                    12.0
# 4                 2022-01-01 04:00:00                     8.0
# ...                               ...                     ...
# 8755              2022-12-31 19:00:00                    36.0
# 8756              2022-12-31 20:00:00                    32.0
# 8757              2022-12-31 21:00:00                    24.0
# 8758              2022-12-31 22:00:00                    32.0
# 8759              2022-12-31 23:00:00                    22.0
#
#       02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# 0                       11.0                     9.0                     8.0
# ...

# %%
list(df6.columns)
# Out:
# ['Zählstelle        Inbetriebnahme',
#  '02-MI-JAN-N 01.04.2015',
#  '02-MI-JAN-S 01.04.2015',
#  '03-MI-SAN-O 01.06.2015',
#  '03-MI-SAN-W 01.06.2015',
#  '06-FK-FRA-O 01.06.2016',
#  '06-FK-FRA-W 01.06.2016',
#  '10-PA-BER-N 01.05.2016',
#  '10-PA-BER-S 01.05.2016',
#  '12-PA-SCH 01.03.2012',
#  '13-CW-PRI 01.04.2015',
#  '15-SP-KLO-N 01.06.2016',
#  '15-SP-KLO-S 01.06.2016',
#  '17-SZ-BRE-O 01.05.2016',
#  '17-SZ-BRE-W 01.05.2016',
#  '18-TS-YOR-O 01.04.2015',
#  '18-TS-YOR-W 01.04.2015',
#  '19-TS-MON 01.05.2015',
#  '20-TS-MAR-N  01.05.2016',
#  '20-TS-MAR-S 01.05.2016',
#  '21-NK-MAY 01.05.2016',
#  '23-TK-KAI 01.05.2016',
#  '24-MH-ALB 01.07.2015',
#  '26-LI-PUP 01.06.2015',
#  '27-RE-MAR 01.05.2015']

# %%
list(df_5years.columns)
# Out:
# ['Zählstelle        Inbetriebnahme',
#  'Jannowitzbrücke Nord',
#  'Jannowitzbrücke Süd',
#  'Invalidenstraße Ost',
#  'Invalidenstraße West',
#  'Frankfurter Allee Ost',
#  'Frankfurter Allee West',
#  'Berliner Straße Nord',
#  'Berliner Straße Süd',
#  'Schwedter Steg',
#  'Prinzregentenstraße',
#  'Klosterstraße Nord',
#  'Klosterstraße Süd',
#  'Breitenbachplatz Ost',
#  'Breitenbachplatz West',
#  'Yorckstraße Ost',
#  'Yorkstraße West',
#  'Monumentenstraße',
#  'Mariendorfer Damm Nord',
#  'Mariendorfer Damm Süd',
#  'Maybachufer',
#  'Kaisersteg',
#  'Alberichstraße',
#  'Paul-und-Paula-Uferweg',
#  'Markstraße',
#  'date',
#  'Time']

# %%
df6= df6.rename(columns={'02-MI-JAN-N 01.04.2015': 'Jannowitzbrücke Nord', '02-MI-JAN-S 01.04.2015': 'Jannowitzbrücke Süd',
                         '03-MI-SAN-O 01.06.2015': 'Invalidenstraße Ost', '03-MI-SAN-W 01.06.2015': 'Invalidenstraße West',
                         '06-FK-FRA-O 01.06.2016': 'Frankfurter Allee Ost', '06-FK-FRA-W 01.06.2016': 'Frankfurter Allee West',
                         '10-PA-BER-N 01.05.2016': 'Berliner Straße Nord', '10-PA-BER-S 01.05.2016': 'Berliner Straße Süd',
                         '12-PA-SCH 01.03.2012': 'Schwedter Steg', '13-CW-PRI 01.04.2015': 'Prinzregentenstraße',
                         '15-SP-KLO-N 01.06.2016': 'Klosterstraße Nord', '15-SP-KLO-S 01.06.2016': 'Klosterstraße Süd',
                         '17-SZ-BRE-O 01.05.2016': 'Breitenbachplatz Ost', '17-SZ-BRE-W 01.05.2016': 'Breitenbachplatz West',
                         '18-TS-YOR-O 01.04.2015': 'Yorckstraße Ost', '18-TS-YOR-W 01.04.2015': 'Yorkstraße West',
                         '19-TS-MON 01.05.2015': 'Monumentenstraße', '20-TS-MAR-N  01.05.2016': 'Mariendorfer Damm Nord',
                         '20-TS-MAR-S 01.05.2016': 'Mariendorfer Damm Süd', '21-NK-MAY 01.05.2016': 'Maybachufer',
                         '23-TK-KAI 01.05.2016': 'Kaisersteg', '24-MH-ALB 01.07.2015': 'Alberichstraße',
                         '26-LI-PUP 01.06.2015': 'Paul-und-Paula-Uferweg', '27-RE-MAR 01.05.2015': 'Markstraße'})
df6
# Out:
#      Zählstelle        Inbetriebnahme  Jannowitzbrücke Nord  \
# 0                 2022-01-01 00:00:00                  10.0
# 1                 2022-01-01 01:00:00                  22.0
# 2                 2022-01-01 02:00:00                  25.0
# 3                 2022-01-01 03:00:00                  12.0
# 4                 2022-01-01 04:00:00                   8.0
# ...                               ...                   ...
# 8755              2022-12-31 19:00:00                  36.0
# 8756              2022-12-31 20:00:00                  32.0
# 8757              2022-12-31 21:00:00                  24.0
# 8758              2022-12-31 22:00:00                  32.0
# 8759              2022-12-31 23:00:00                  22.0
#
#       Jannowitzbrücke Süd  Invalidenstraße Ost  Invalidenstraße West  \
# 0                    11.0                  9.0                   8.0
# 1                    13.0                 12.0                   6.0
# ...

# %%
list(df6.columns)
# Out:
# ['Zählstelle        Inbetriebnahme',
#  'Jannowitzbrücke Nord',
#  'Jannowitzbrücke Süd',
#  'Invalidenstraße Ost',
#  'Invalidenstraße West',
#  'Frankfurter Allee Ost',
#  'Frankfurter Allee West',
#  'Berliner Straße Nord',
#  'Berliner Straße Süd',
#  'Schwedter Steg',
#  'Prinzregentenstraße',
#  'Klosterstraße Nord',
#  'Klosterstraße Süd',
#  'Breitenbachplatz Ost',
#  'Breitenbachplatz West',
#  'Yorckstraße Ost',
#  'Yorkstraße West',
#  'Monumentenstraße',
#  'Mariendorfer Damm Nord',
#  'Mariendorfer Damm Süd',
#  'Maybachufer',
#  'Kaisersteg',
#  'Alberichstraße',
#  'Paul-und-Paula-Uferweg',
#  'Markstraße',
#  'date',
#  'Time']

# %%
df6['date'] = df6['Zählstelle        Inbetriebnahme'].dt.date
df6['Time'] = df6['Zählstelle        Inbetriebnahme'].dt.time


df6
# Out:
#      Zählstelle        Inbetriebnahme  Jannowitzbrücke Nord  \
# 0                 2022-01-01 00:00:00                  10.0
# 1                 2022-01-01 01:00:00                  22.0
# 2                 2022-01-01 02:00:00                  25.0
# 3                 2022-01-01 03:00:00                  12.0
# 4                 2022-01-01 04:00:00                   8.0
# ...                               ...                   ...
# 8755              2022-12-31 19:00:00                  36.0
# 8756              2022-12-31 20:00:00                  32.0
# 8757              2022-12-31 21:00:00                  24.0
# 8758              2022-12-31 22:00:00                  32.0
# 8759              2022-12-31 23:00:00                  22.0
#
#       Jannowitzbrücke Süd  Invalidenstraße Ost  Invalidenstraße West  \
# 0                    11.0                  9.0                   8.0
# 1                    13.0                 12.0                   6.0
# ...

# %%
df_5years
# Out:
#      Zählstelle        Inbetriebnahme  Jannowitzbrücke Nord  \
# 0                 2021-01-01 00:00:00                   5.0
# 1                 2021-01-01 01:00:00                  21.0
# 2                 2021-01-01 02:00:00                  28.0
# 3                 2021-01-01 03:00:00                  36.0
# 4                 2021-01-01 04:00:00                  24.0
# ...                               ...                   ...
# 8755              2017-12-31 19:00:00                  29.0
# 8756              2017-12-31 20:00:00                  31.0
# 8757              2017-12-31 21:00:00                  21.0
# 8758              2017-12-31 22:00:00                  11.0
# 8759              2017-12-31 23:00:00                   7.0
#
#       Jannowitzbrücke Süd  Invalidenstraße Ost  Invalidenstraße West  \
# 0                     6.0                  4.0                   2.0
# 1                    14.0                 12.0                  18.0
# ...

# %%
df6
# Out:
#      Zählstelle        Inbetriebnahme  Jannowitzbrücke Nord  \
# 0                 2022-01-01 00:00:00                  10.0
# 1                 2022-01-01 01:00:00                  22.0
# 2                 2022-01-01 02:00:00                  25.0
# 3                 2022-01-01 03:00:00                  12.0
# 4                 2022-01-01 04:00:00                   8.0
# ...                               ...                   ...
# 8755              2022-12-31 19:00:00                  36.0
# 8756              2022-12-31 20:00:00                  32.0
# 8757              2022-12-31 21:00:00                  24.0
# 8758              2022-12-31 22:00:00                  32.0
# 8759              2022-12-31 23:00:00                  22.0
#
#       Jannowitzbrücke Süd  Invalidenstraße Ost  Invalidenstraße West  \
# 0                    11.0                  9.0                   8.0
# 1                    13.0                 12.0                   6.0
# ...

# %%
df10=df_5years.append(df6)
df10
# Out:
#      Zählstelle        Inbetriebnahme  Jannowitzbrücke Nord  \
# 0                 2021-01-01 00:00:00                   5.0
# 1                 2021-01-01 01:00:00                  21.0
# 2                 2021-01-01 02:00:00                  28.0
# 3                 2021-01-01 03:00:00                  36.0
# 4                 2021-01-01 04:00:00                  24.0
# ...                               ...                   ...
# 8755              2022-12-31 19:00:00                  36.0
# 8756              2022-12-31 20:00:00                  32.0
# 8757              2022-12-31 21:00:00                  24.0
# 8758              2022-12-31 22:00:00                  32.0
# 8759              2022-12-31 23:00:00                  22.0
#
#       Jannowitzbrücke Süd  Invalidenstraße Ost  Invalidenstraße West  \
# 0                     6.0                  4.0                   2.0
# 1                    14.0                 12.0                  18.0
# ...

# %%
df10.to_excel("6_years.xlsx")
