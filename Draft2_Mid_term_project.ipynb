# %%
import openpyxl
workbook=openpyxl.load_workbook('gesamtdatei_stundenwerte1.xlsx')
workbook.get_sheet_names()
# Out:
# <ipython-input-42-1075f6671aef>:3: DeprecationWarning: Call to deprecated function get_sheet_names (Use wb.sheetnames).
#   workbook.get_sheet_names()
# ['Hinweise',
#  'Legende',
#  'Standortdaten',
#  'Jahresdatei 2012',
#  'Jahresdatei 2013',
#  'Jahresdatei 2014',
#  'Jahresdatei 2015',
#  'Jahresdatei 2016',
#  'Jahresdatei 2017',
#  'Jahresdatei 2018',
#  'Jahresdatei 2019',
#  'Jahresdatei 2020',
#  'Jahresdatei 2021']

# %%
print(workbook.sheetnames)
# Out:
# ['Hinweise', 'Legende', 'Standortdaten', 'Jahresdatei 2012', 'Jahresdatei 2013', 'Jahresdatei 2014', 'Jahresdatei 2015', 'Jahresdatei 2016', 'Jahresdatei 2017', 'Jahresdatei 2018', 'Jahresdatei 2019', 'Jahresdatei 2020', 'Jahresdatei 2021']

# %%
Standortdaten=workbook.get_sheet_by_name('Standortdaten')
# Out:
# <ipython-input-18-ccda1a4182f4>:1: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   Standortdaten=workbook.get_sheet_by_name('Standortdaten')

# %%
workbook.remove_sheet(Standortdaten)
# Out:
# <ipython-input-20-010f6b194d74>:1: DeprecationWarning: Call to deprecated function remove_sheet (Use wb.remove(worksheet) or del wb[sheetname]).
#   workbook.remove_sheet(Standortdaten)

# %%
Hinweise=workbook.get_sheet_by_name('Hinweise')
Legende=workbook.get_sheet_by_name('Legende')
# Out:
# <ipython-input-21-f7581d76972b>:1: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   Hinweise=workbook.get_sheet_by_name('Hinweise')
# <ipython-input-21-f7581d76972b>:2: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   Legende=workbook.get_sheet_by_name('Legende')

# %%
workbook.remove_sheet(Hinweise)
# Out:
# <ipython-input-22-97410fd07ff2>:1: DeprecationWarning: Call to deprecated function remove_sheet (Use wb.remove(worksheet) or del wb[sheetname]).
#   workbook.remove_sheet(Hinweise)

# %%
workbook.remove_sheet(Legende)
# Out:
# <ipython-input-23-713b7318e16e>:1: DeprecationWarning: Call to deprecated function remove_sheet (Use wb.remove(worksheet) or del wb[sheetname]).
#   workbook.remove_sheet(Legende)

# %%
print(workbook.sheetnames)
# Out:
# ['Jahresdatei 2012', 'Jahresdatei 2013', 'Jahresdatei 2014', 'Jahresdatei 2015', 'Jahresdatei 2016', 'Jahresdatei 2017', 'Jahresdatei 2018', 'Jahresdatei 2019', 'Jahresdatei 2020', 'Jahresdatei 2021']

# %%
workbook.sheetnames
# Out:
# ['Jahresdatei 2012',
#  'Jahresdatei 2013',
#  'Jahresdatei 2014',
#  'Jahresdatei 2015',
#  'Jahresdatei 2016',
#  'Jahresdatei 2017',
#  'Jahresdatei 2018',
#  'Jahresdatei 2019',
#  'Jahresdatei 2020',
#  'Jahresdatei 2021']

# %%
from datetime import datetime

import numpy as np
import pandas as pd

# %%
xls = pd.ExcelFile('gesamtdatei_stundenwerte1.xlsx')
df1 = pd.read_excel(xls, 'Jahresdatei 2021')
df1
# Out:
#      Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0                 2021-01-01 00:00:00                     5.0
# 1                 2021-01-01 01:00:00                    21.0
# 2                 2021-01-01 02:00:00                    28.0
# 3                 2021-01-01 03:00:00                    36.0
# 4                 2021-01-01 04:00:00                    24.0
# ...                               ...                     ...
# 8755              2021-12-31 19:00:00                    32.0
# 8756              2021-12-31 20:00:00                    17.0
# 8757              2021-12-31 21:00:00                    13.0
# 8758              2021-12-31 22:00:00                    25.0
# 8759              2021-12-31 23:00:00                    10.0
#
#       02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# 0                        6.0                     4.0                     2.0
# ...

# %%
#df1.info()
#df1['Date']= pd.to_datetime(df1['Zählstelle Inbetriebnahme'])

df1['Zählstelle        Inbetriebnahme']
# Out:
# 0      2021-01-01 00:00:00
# 1      2021-01-01 01:00:00
# 2      2021-01-01 02:00:00
# 3      2021-01-01 03:00:00
# 4      2021-01-01 04:00:00
#                ...
# 8755   2021-12-31 19:00:00
# 8756   2021-12-31 20:00:00
# 8757   2021-12-31 21:00:00
# 8758   2021-12-31 22:00:00
# 8759   2021-12-31 23:00:00
# Name: Zählstelle        Inbetriebnahme, Length: 8760, dtype: datetime64[ns]

# %%
df1['date'] = df1['Zählstelle        Inbetriebnahme'].dt.date
df1['Time'] = df1['Zählstelle        Inbetriebnahme'].dt.time
df1
# Out:
#      Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0                 2021-01-01 00:00:00                     5.0
# 1                 2021-01-01 01:00:00                    21.0
# 2                 2021-01-01 02:00:00                    28.0
# 3                 2021-01-01 03:00:00                    36.0
# 4                 2021-01-01 04:00:00                    24.0
# ...                               ...                     ...
# 8755              2021-12-31 19:00:00                    32.0
# 8756              2021-12-31 20:00:00                    17.0
# 8757              2021-12-31 21:00:00                    13.0
# 8758              2021-12-31 22:00:00                    25.0
# 8759              2021-12-31 23:00:00                    10.0
#
#       02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# 0                        6.0                     4.0                     2.0
# ...

# %%
xls2 = pd.ExcelFile('export_2021.xlsx')
df2 = pd.read_excel(xls2, 'Export')
df2
# Out:
#            date  tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# 0    2021-01-01   1.0   0.1   1.8   1.2   NaN  195.0   8.2  20.4  1007.7   NaN
# 1    2021-01-02   0.8  -1.1   2.9   0.0   NaN  176.0   8.1  22.2  1014.5   NaN
# 2    2021-01-03   0.3  -0.2   0.7   7.2   NaN   57.0  18.2  37.0  1015.8   NaN
# 3    2021-01-04   0.8   0.5   1.0   3.4   NaN   51.0  14.9  31.5  1017.2   NaN
# 4    2021-01-05   1.3   0.6   2.1   2.3   NaN   30.0  15.1  31.5  1016.9   NaN
# ..          ...   ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 360  2021-12-27  -4.6  -8.2  -2.1   0.0   NaN  114.0  17.8  35.2  1008.9   NaN
# 361  2021-12-28  -0.2  -3.2   2.0   2.4   NaN  131.0  17.0  33.3  1000.5   NaN
# 362  2021-12-29   3.0   1.9   3.9   1.4   NaN  232.0   8.5  20.4  1004.1   NaN
# 363  2021-12-30   7.6   3.9  11.4   3.3   NaN  233.0  14.1  38.9  1011.1   NaN
# 364  2021-12-31  11.8  11.3  12.4   5.2   NaN  257.0  20.8  42.6  1014.4   NaN
#
# [365 rows x 11 columns]

# %%
#df = pd.concat([df1, df2, numerical_df], axis=1)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    365 non-null    object
#  1   tavg    364 non-null    float64
#  2   tmin    364 non-null    float64
#  3   tmax    364 non-null    float64
#  4   prcp    364 non-null    float64
#  5   snow    0 non-null      float64
#  6   wdir    364 non-null    float64
#  7   wspd    364 non-null    float64
#  8   wpgt    364 non-null    float64
#  9   pres    364 non-null    float64
#  10  tsun    0 non-null      float64
# dtypes: float64(10), object(1)
# memory usage: 31.5+ KB

# %%
df1
# Out:
#      Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0                 2021-01-01 00:00:00                     5.0
# 1                 2021-01-01 01:00:00                    21.0
# 2                 2021-01-01 02:00:00                    28.0
# 3                 2021-01-01 03:00:00                    36.0
# 4                 2021-01-01 04:00:00                    24.0
# ...                               ...                     ...
# 8755              2021-12-31 19:00:00                    32.0
# 8756              2021-12-31 20:00:00                    17.0
# 8757              2021-12-31 21:00:00                    13.0
# 8758              2021-12-31 22:00:00                    25.0
# 8759              2021-12-31 23:00:00                    10.0
#
#       02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# 0                        6.0                     4.0                     2.0
# ...

# %%
df= pd.merge(df1, df2, how='left', on='date')
df
# Out:
#      Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0                 2021-01-01 00:00:00                     5.0
# 1                 2021-01-01 01:00:00                    21.0
# 2                 2021-01-01 02:00:00                    28.0
# 3                 2021-01-01 03:00:00                    36.0
# 4                 2021-01-01 04:00:00                    24.0
# ...                               ...                     ...
# 8755              2021-12-31 19:00:00                    32.0
# 8756              2021-12-31 20:00:00                    17.0
# 8757              2021-12-31 21:00:00                    13.0
# 8758              2021-12-31 22:00:00                    25.0
# 8759              2021-12-31 23:00:00                    10.0
#
#       02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# 0                        6.0                     4.0                     2.0
# ...
