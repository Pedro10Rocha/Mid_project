# %%
import pandas as pd

df = pd.concat(pd.read_excel('gesamtdatei_stundenwerte1.xlsx', sheet_name=None), ignore_index=True)

# %%
import pandas as pd
df=pd.ExcelFile('gesamtdatei_stundenwerte1.xlsx')
df.sheet_names
# Out:
# ['Hinweise',
#  'Legende',
#  'Standortdaten',
#  'Jahresdatei 2012',
#  'Jahresdatei 2013',
#  'Jahresdatei 2014',
#  'Jahresdatei 2015',
#  'Jahresdatei 2016',
#  'Jahresdatei 2017',
#  'Jahresdatei 2018',
#  'Jahresdatei 2019',
#  'Jahresdatei 2020',
#  'Jahresdatei 2021']

# %%
all_dfs= pd.read_excel('gesamtdatei_stundenwerte1.xlsx', sheet_name=None)

# %%
df = pd.concat(all_dfs, ignore_index=True)

# %%
df = pd.concat(pd.read_excel('gesamtdatei_stundenwerte1.xlsx', sheet_name=None), ignore_index=True)

# %%
df
# Out:
#        Unnamed: 0                                         Unnamed: 1  \
# 0             NaN                                Datenbereitsteller:
# 1             NaN  Senatsverwaltung für Umwelt, Mobilität, Verbra...
# 2             NaN                                                NaN
# 3             NaN                                                NaN
# 4             NaN                                          Hinweise:
# ...           ...                                                ...
# 96498         NaN                                                NaN
# 96499         NaN                                                NaN
# 96500         NaN                                                NaN
# 96501         NaN                                                NaN
# 96502         NaN                                                NaN
#
#       Unnamed: 2 Zählstelle Beschreibung - Fahrtrichtung  Breitengrad  \
# ...

# %%
res=len(df.sheet_names)
res
# Out:
# 13

# %%
xl=pd.ExcelFile('gesamtdatei_stundenwerte1.xlsx', sheet_name=None)
all_data_df=pd.concat(xl.value())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-5885a1880149> in <module>
# ----> 1 xl=pd.ExcelFile('gesamtdatei_stundenwerte1.xlsx', sheet_name=None)
#       2 all_data_df=pd.concat(xl.value())
#
# TypeError: __init__() got an unexpected keyword argument 'sheet_name'

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('gesamtdatei_stundenwerte1.xlsx', sheet_name='Standortdaten')
df
# Out:
#      Zählstelle Beschreibung - Fahrtrichtung  Breitengrad  Längengrad  \
# 0     12-PA-SCH               Schwedter Steg    52.548836   13.400367
# 1   02-MI-JAN-N         Jannowitzbrücke Nord    52.513932   13.417835
# 2   02-MI-JAN-S          Jannowitzbrücke Süd    52.513943   13.417611
# 3     13-CW-PRI          Prinzregentenstraße    52.488136   13.333120
# 4   18-TS-YOR-O              Yorckstraße Ost    52.491938   13.373472
# 5   18-TS-YOR-W              Yorkstraße West    52.492280   13.373210
# 6     19-TS-MON             Monumentenstraße    52.488117   13.369785
# 7     27-RE-MAR                   Markstraße    52.558190   13.364944
# 8   03-MI-SAN-O          Invalidenstraße Ost    52.527177   13.372016
# 9   03-MI-SAN-W         Invalidenstraße West    52.527686   13.373105
# 10  05-FK-OBB-O           Oberbaumbrücke Ost    52.501199   13.445060
# 11  05-FK-OBB-W          Oberbaumbrücke West    52.501276   13.444867
# ...

# %%
df1 = pd.read_excel('gesamtdatei_stundenwerte.xlsx', sheet_name='Jahresdatei 2021')
df1
# Out:
#       Unnamed: 0 Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0              0              2021-01-01 00:00:00                     5.0
# 1              1              2021-01-01 01:00:00                    21.0
# 2              2              2021-01-01 02:00:00                    28.0
# 3              3              2021-01-01 03:00:00                    36.0
# 4              4              2021-01-01 04:00:00                    24.0
# ...          ...                              ...                     ...
# 8755        8755              2021-12-31 19:00:00                    32.0
# 8756        8756              2021-12-31 20:00:00                    17.0
# 8757        8757              2021-12-31 21:00:00                    13.0
# 8758        8758              2021-12-31 22:00:00                    25.0
# 8759        8759              2021-12-31 23:00:00                    10.0
#
#       02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# ...

# %%
import datetime

# %%
#df['month'] = pd.DatetimeIndex(df['Zählstelle Inbetriebnahme']).month

#df['month'] = df['Zählstelle Inbetriebnahme'].dt.month
#df['Month'] = df['2021-12-31 23:00:00'].dt.strftime('%m')

#df1['Year'] = '2021'

# %%
#df1.to_excel('gesamtdatei_stundenwerte.xlsx', sheet_name='Jahresdatei 2021')

# %%
#import numpy as np
#import pandas as pd

#df1 = pd.read_excel('gesamtdatei_stundenwerte.xlsx', sheet_name='Jahresdatei 2021')
#df1
# Out:
#       Unnamed: 0 Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0              0              2021-01-01 00:00:00                     5.0
# 1              1              2021-01-01 01:00:00                    21.0
# 2              2              2021-01-01 02:00:00                    28.0
# 3              3              2021-01-01 03:00:00                    36.0
# 4              4              2021-01-01 04:00:00                    24.0
# ...          ...                              ...                     ...
# 8755        8755              2021-12-31 19:00:00                    32.0
# 8756        8756              2021-12-31 20:00:00                    17.0
# 8757        8757              2021-12-31 21:00:00                    13.0
# 8758        8758              2021-12-31 22:00:00                    25.0
# 8759        8759              2021-12-31 23:00:00                    10.0
#
#       02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# ...

# %%
#df1['02-MI-JAN-N 01.04.2015'].append(df1['02-MI-JAN-S 01.04.2015']).reset_index(drop=True)
#df1

#df1.stack().reset_index()

# %%
#df1['Location']=df1['02-MI-JAN-N 01.04.2015'].apply(lambda x: 'Jannowitzbrücke Nord') 
#df1
# Out:
#       Unnamed: 0 Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0              0              2021-01-01 00:00:00                     5.0
# 1              1              2021-01-01 01:00:00                    21.0
# 2              2              2021-01-01 02:00:00                    28.0
# 3              3              2021-01-01 03:00:00                    36.0
# 4              4              2021-01-01 04:00:00                    24.0
# ...          ...                              ...                     ...
# 8755        8755              2021-12-31 19:00:00                    32.0
# 8756        8756              2021-12-31 20:00:00                    17.0
# 8757        8757              2021-12-31 21:00:00                    13.0
# 8758        8758              2021-12-31 22:00:00                    25.0
# 8759        8759              2021-12-31 23:00:00                    10.0
#
#       02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# ...

# %%
AllDataSheet =
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-a6fefe7d4d80> in <module>
# ----> 1 newWorkbook.sheets.count
#
# AttributeError: 'Workbook' object has no attribute 'sheets'
