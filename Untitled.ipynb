# %%
import pandas as pd
df = pd.ExcelFile('gesamtdatei_stundenwerte.xlsx')
df = pd.read_excel(df, 'Jahresdatei 2012')
df = pd.DataFrame(df)
df
# Out:
#       Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0                  2012-01-01 00:00:00                     NaN
# 1                  2012-01-01 01:00:00                     NaN
# 2                  2012-01-01 02:00:00                     NaN
# 3                  2012-01-01 03:00:00                     NaN
# 4                  2012-01-01 04:00:00                     NaN
# ...                                ...                     ...
# 17539              2013-12-31 19:00:00                     NaN
# 17540              2013-12-31 20:00:00                     NaN
# 17541              2013-12-31 21:00:00                     NaN
# 17542              2013-12-31 22:00:00                     NaN
# 17543              2013-12-31 23:00:00                     NaN
#
#        02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# 0                         NaN                     NaN                     NaN
# ...

# %%
# Out:
#       Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0                  2012-01-01 00:00:00                     NaN
# 1                  2012-01-01 01:00:00                     NaN
# 2                  2012-01-01 02:00:00                     NaN
# 3                  2012-01-01 03:00:00                     NaN
# 4                  2012-01-01 04:00:00                     NaN
# ...                                ...                     ...
# 17539              2013-12-31 19:00:00                     NaN
# 17540              2013-12-31 20:00:00                     NaN
# 17541              2013-12-31 21:00:00                     NaN
# 17542              2013-12-31 22:00:00                     NaN
# 17543              2013-12-31 23:00:00                     NaN
#
#        02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# 0                         NaN                     NaN                     NaN
# ...
